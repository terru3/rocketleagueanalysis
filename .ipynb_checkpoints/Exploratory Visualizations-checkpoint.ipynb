# %% [markdown]
# # RL Analysis Continued—Exploratory Visualizations

# %% [markdown]
# ## Part II: Exploratory Visualizations

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Loading in our dataframes

# %%
df = pd.read_pickle("/Users/Terru/Desktop/RL-Analysis/dataframes/df.pkl")
blue_players = pd.read_pickle("/Users/Terru/Desktop/RL-Analysis/dataframes/blue_players.pkl")
orange_players = pd.read_pickle("/Users/Terru/Desktop/RL-Analysis/dataframes/orange_players.pkl")

# %% [markdown]
# ### Investigating what we have to work with

# %%
blue_players.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114783 entries, 0 to 114782
# Data columns (total 101 columns):
#  #    Column                                           Dtype
# ---   ------                                           -----
#  0    series_id                                        int64
#  1    player._id                                       object
#  2    player.slug                                      object
#  3    player.tag                                       object
#  4    player.country                                   object
#  5    stats.core.shots                                 float64
#  6    stats.core.goals                                 float64
#  7    stats.core.saves                                 float64
#  8    stats.core.assists                               float64
#  9    stats.core.score                                 float64
#  10   stats.core.shootingPercentage                    float64
#  11   advanced.goalParticipation                       float64
#  12   advanced.rating                                  float64
#  13   stats.boost.bpm                                  float64
#  14   stats.boost.bcpm                                 float64
#  15   stats.boost.avgAmount                            float64
#  16   stats.boost.amountCollected                      float64
#  17   stats.boost.amountStolen                         float64
#  18   stats.boost.amountCollectedBig                   float64
#  19   stats.boost.amountStolenBig                      float64
#  20   stats.boost.amountCollectedSmall                 float64
#  21   stats.boost.amountStolenSmall                    float64
#  22   stats.boost.countCollectedBig                    float64
#  23   stats.boost.countStolenBig                       float64
#  24   stats.boost.countCollectedSmall                  float64
#  25   stats.boost.countStolenSmall                     float64
#  26   stats.boost.amountOverfill                       float64
#  27   stats.boost.amountOverfillStolen                 float64
#  28   stats.boost.amountUsedWhileSupersonic            float64
#  29   stats.boost.timeZeroBoost                        float64
#  30   stats.boost.percentZeroBoost                     float64
#  31   stats.boost.timeFullBoost                        float64
#  32   stats.boost.percentFullBoost                     float64
#  33   stats.boost.timeBoost0To25                       float64
#  34   stats.boost.timeBoost25To50                      float64
#  35   stats.boost.timeBoost50To75                      float64
#  36   stats.boost.timeBoost75To100                     float64
#  37   stats.boost.percentBoost0To25                    float64
#  38   stats.boost.percentBoost25To50                   float64
#  39   stats.boost.percentBoost50To75                   float64
#  40   stats.boost.percentBoost75To100                  float64
#  41   stats.movement.avgSpeed                          float64
#  42   stats.movement.totalDistance                     float64
#  43   stats.movement.timeSupersonicSpeed               float64
#  44   stats.movement.timeBoostSpeed                    float64
#  45   stats.movement.timeSlowSpeed                     float64
#  46   stats.movement.timeGround                        float64
#  47   stats.movement.timeLowAir                        float64
#  48   stats.movement.timeHighAir                       float64
#  49   stats.movement.timePowerslide                    float64
#  50   stats.movement.countPowerslide                   float64
#  51   stats.movement.avgPowerslideDuration             float64
#  52   stats.movement.avgSpeedPercentage                float64
#  53   stats.movement.percentSlowSpeed                  float64
#  54   stats.movement.percentBoostSpeed                 float64
#  55   stats.movement.percentSupersonicSpeed            float64
#  56   stats.movement.percentGround                     float64
#  57   stats.movement.percentLowAir                     float64
#  58   stats.movement.percentHighAir                    float64
#  59   stats.positioning.avgDistanceToBall              float64
#  60   stats.positioning.avgDistanceToBallPossession    float64
#  61   stats.positioning.avgDistanceToBallNoPossession  float64
#  62   stats.positioning.avgDistanceToMates             float64
#  63   stats.positioning.timeDefensiveThird             float64
#  64   stats.positioning.timeNeutralThird               float64
#  65   stats.positioning.timeOffensiveThird             float64
#  66   stats.positioning.timeDefensiveHalf              float64
#  67   stats.positioning.timeOffensiveHalf              float64
#  68   stats.positioning.timeBehindBall                 float64
#  69   stats.positioning.timeInfrontBall                float64
#  70   stats.positioning.timeMostBack                   float64
#  71   stats.positioning.timeMostForward                float64
#  72   stats.positioning.goalsAgainstWhileLastDefender  float64
#  73   stats.positioning.timeClosestToBall              float64
#  74   stats.positioning.timeFarthestFromBall           float64
#  75   stats.positioning.percentDefensiveThird          float64
#  76   stats.positioning.percentOffensiveThird          float64
#  77   stats.positioning.percentNeutralThird            float64
#  78   stats.positioning.percentDefensiveHalf           float64
#  79   stats.positioning.percentOffensiveHalf           float64
#  80   stats.positioning.percentBehindBall              float64
#  81   stats.positioning.percentInfrontBall             float64
#  82   stats.positioning.percentMostBack                float64
#  83   stats.positioning.percentMostForward             float64
#  84   stats.positioning.percentClosestToBall           float64
#  85   stats.positioning.percentFarthestFromBall        float64
#  86   stats.demo.inflicted                             float64
#  87   stats.demo.taken                                 float64
#  88   player.name                                      object
#  89   player.accounts                                  object
#  90   player.relevant                                  object
#  91   player.team._id                                  object
#  92   player.team.slug                                 object
#  93   player.team.name                                 object
#  94   player.team.region                               object
#  95   player.team.image                                object
#  96   player.team.relevant                             object
#  97   player.coach                                     object
#  98   player.substitute                                object
#  99   tier                                             object
#  100  date                                             datetime64[ns]
# dtypes: datetime64[ns](1), float64(83), int64(1), object(16)
# memory usage: 88.4+ MB

# %% [markdown]
# The main quantitative analytical features we are likely to be interested in include:
# -Shots
# -Goals
# -Saves
# -Assists
# -Score
# -Shooting percentage
# -Goal participation
# -Rating
# -Boost used per minute (bpm)
# -Boost amount stolen
# -Time spent at 0-25/25-50/50-75/75-100 boost
# -Average speed
# -Time supersonic
# -Powerslide count
# -Percentage of time on the ground/low air/high air
# -Average distance to ball
# -Percentage of time in defensive/neutral/offensive third, defensive/offensive half
# -Time behind/in front of the ball
# -Number of goals against while last defender
# -Demos inflicted, and
# -Demos taken

# %% [markdown]
# We'll have to be careful about the data we're given, and perform feature engineering as needed to obtain the numerical data we actually want. For example, every variable is given as a total across an entire series, but if we want, say, average score per game, we'll need to access the data for that given series in *df*, then sum up the blue and orange team game scores to find the total number of games in the series to divide by. Some stats can't be feature engineered in this way, though, such as shooting percentage (there's no way we can learn what a player's shooting percentage was in each individual game).

# %%
pd.options.display.max_columns = None
blue_players
# Out:
#         series_id                player._id     player.slug  player.tag  \
# 0               0  5f3d8fdd95f40596eae23f4d    3f4d-caiotg1     CaioTG1
# 1               0  5f3d8fdd95f40596eae23f65    3f65-protomz     Protomz
# 2               0  5f99d0c8786e9eb85284db78    db78-noiisey     Noiisey
# 3               1  5f3d8fdd95f40596eae23d6e   3d6e-darkfire    DarkFire
# 4               1  5f3d8fdd95f40596eae23d72    3d72-torment     Torment
# ...           ...                       ...             ...         ...
# 114778      38259  5f3d8fdd95f40596eae2433d        433d-sad         Sad
# 114779      38259  5f3d8fdd95f40596eae2433c     433c-nxghtt      nxghtt
# 114780      38260  601a310ed35e6ea972758280  8280-kiileerrz  Kiileerrz.
# 114781      38260  5f5ae871c6cbf591c568a545        a545-rw9        Rw9.
# 114782      38260  5f3d8fdd95f40596eae24391       4391-nadr        Nadr
#
#        player.country  stats.core.shots  stats.core.goals  stats.core.saves  \
# 0                  br              14.0               5.0               7.0
# 1                  br              15.0               4.0               3.0
# 2                  br              12.0               3.0               5.0
# 3                  us              13.0               1.0               6.0
# 4                  us               5.0               2.0               1.0
# ...               ...               ...               ...               ...
# 114778             br              12.0               4.0               8.0
# 114779             br              12.0               5.0               8.0
# 114780             sa              22.0               8.0               8.0
# 114781             sa              15.0               8.0               9.0
# 114782             sa              18.0               3.0               7.0
#
#         stats.core.assists  stats.core.score  stats.core.shootingPercentage  \
# 0                      6.0            1620.0                      35.714286
# 1                      1.0            1255.0                      26.666667
# 2                      3.0            1280.0                      25.000000
# 3                      3.0            1005.0                       7.692308
# 4                      3.0             790.0                      40.000000
# ...                    ...               ...                            ...
# 114778                 3.0            1921.0                      33.333333
# 114779                 4.0            2101.0                      41.666667
# 114780                 3.0            2744.0                      36.363636
# 114781                 2.0            2626.0                      53.333333
# 114782                 8.0            2028.0                      16.666667
#
#         advanced.goalParticipation  advanced.rating  stats.boost.bpm  \
# 0                        91.666667         1.280581              NaN
# 1                        41.666667         0.668225              NaN
# 2                        50.000000         0.769377              NaN
# 3                        57.142857         0.710201           1726.0
# 4                        71.428571         0.579312           1231.0
# ...                            ...              ...              ...
# 114778                   50.000000         1.012708           2249.0
# 114779                   64.285714         1.262553           1800.0
# 114780                   57.894737         1.258895           2701.0
# 114781                   52.631579         1.152584           2575.0
# 114782                   57.894737         1.045153           2085.0
#
#         stats.boost.bcpm  stats.boost.avgAmount  stats.boost.amountCollected  \
# 0                    NaN                    NaN                          NaN
# 1                    NaN                    NaN                          NaN
# 2                    NaN                    NaN                          NaN
# 3             1826.76614                 187.33                      10144.0
# 4             1215.99203                 166.01                       6751.0
# ...                  ...                    ...                          ...
# 114778        2343.02287                 240.60                      14755.0
# 114779        1903.54292                 258.42                      11969.0
# 114780        2821.92647                 293.40                      15966.0
# 114781        2741.93510                 292.13                      15492.0
# 114782        2190.91083                 241.94                      12375.0
#
#         stats.boost.amountStolen  stats.boost.amountCollectedBig  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                         2293.0                          7701.0
# 4                         1475.0                          4625.0
# ...                          ...                             ...
# 114778                    2772.0                          9836.0
# 114779                    2859.0                          8340.0
# 114780                    3647.0                         11324.0
# 114781                    2155.0                         11628.0
# 114782                    3052.0                          7623.0
#
#         stats.boost.amountStolenBig  stats.boost.amountCollectedSmall  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                            1632.0                            2443.0
# 4                             824.0                            2126.0
# ...                             ...                               ...
# 114778                       1607.0                            4919.0
# 114779                       1887.0                            3629.0
# 114780                       2092.0                            4642.0
# 114781                       1129.0                            3864.0
# 114782                       1566.0                            4752.0
#
#         stats.boost.amountStolenSmall  stats.boost.countCollectedBig  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                               661.0                           87.0
# 4                               651.0                           52.0
# ...                               ...                            ...
# 114778                         1165.0                          121.0
# 114779                          972.0                          104.0
# 114780                         1555.0                          139.0
# 114781                         1026.0                          146.0
# 114782                         1486.0                           86.0
#
#         stats.boost.countStolenBig  stats.boost.countCollectedSmall  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                             18.0                            211.0
# 4                              9.0                            183.0
# ...                            ...                              ...
# 114778                        19.0                            430.0
# 114779                        22.0                            316.0
# 114780                        26.0                            393.0
# 114781                        14.0                            340.0
# 114782                        17.0                            405.0
#
#         stats.boost.countStolenSmall  stats.boost.amountOverfill  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                               59.0                       948.0
# 4                               56.0                       591.0
# ...                              ...                         ...
# 114778                         105.0                      2345.0
# 114779                          85.0                      2236.0
# 114780                         139.0                      2405.0
# 114781                          88.0                      3041.0
# 114782                         127.0                      1054.0
#
#         stats.boost.amountOverfillStolen  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                  179.0
# 4                                   81.0
# ...                                  ...
# 114778                             262.0
# 114779                             324.0
# 114780                             569.0
# 114781                             278.0
# 114782                             138.0
#
#         stats.boost.amountUsedWhileSupersonic  stats.boost.timeZeroBoost  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                      1395.0                     165.11
# 4                                       434.0                     238.32
# ...                                       ...                        ...
# 114778                                 1774.0                     246.90
# 114779                                 1606.0                     155.90
# 114780                                 2115.0                     250.26
# 114781                                 2342.0                     217.12
# 114782                                 1034.0                     357.59
#
#         stats.boost.percentZeroBoost  stats.boost.timeFullBoost  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                           9.912478                     161.33
# 4                          14.289703                     134.33
# ...                              ...                        ...
# 114778                     12.920296                     203.84
# 114779                      8.270928                     257.16
# 114780                     12.225161                     228.93
# 114781                     10.650660                     280.31
# 114782                     17.466166                     220.14
#
#         stats.boost.percentFullBoost  stats.boost.timeBoost0To25  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                           9.675323                      512.37
# 4                           8.072612                      566.26
# ...                              ...                         ...
# 114778                     10.697898                      703.97
# 114779                     13.502307                      539.08
# 114780                     11.232509                      763.80
# 114781                     13.862471                      693.07
# 114782                     10.925628                      872.40
#
#         stats.boost.timeBoost25To50  stats.boost.timeBoost50To75  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                            282.88                       260.13
# 4                            373.09                       204.96
# ...                             ...                          ...
# 114778                       435.91                       287.58
# 114779                       401.38                       349.17
# 114780                       427.35                       298.83
# 114781                       499.60                       336.40
# 114782                       553.19                       216.01
#
#         stats.boost.timeBoost75To100  stats.boost.percentBoost0To25  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                             316.47                      29.880524
# 4                             194.30                      33.884019
# ...                              ...                            ...
# 114778                        487.69                      36.861690
# 114779                        609.71                      28.367720
# 114780                        566.26                      36.930651
# 114781                        532.36                      33.590431
# 114782                        390.56                      42.746657
#
#         stats.boost.percentBoost25To50  stats.boost.percentBoost50To75  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                            16.524943                       15.152595
# 4                            22.233635                       12.247998
# ...                                ...                             ...
# 114778                       23.103108                       14.769108
# 114779                       20.715334                       18.432859
# 114780                       20.859804                       14.575056
# 114781                       24.126990                       16.489634
# 114782                       27.055593                       10.654303
#
#         stats.boost.percentBoost75To100  stats.movement.avgSpeed  \
# 0                                   NaN                      NaN
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                             18.441940                   6014.0
# 4                             11.634346                   5484.0
# ...                                 ...                      ...
# 114778                        25.266096                   8107.0
# 114779                        32.484086                   7628.0
# 114780                        27.634490                   9577.0
# 114781                        25.792948                   9576.0
# 114782                        19.543443                   8770.0
#
#         stats.movement.totalDistance  stats.movement.timeSupersonicSpeed  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                          1967315.0                              187.43
# 4                          1783581.0                               91.42
# ...                              ...                                 ...
# 114778                     2973364.0                              389.08
# 114779                     2790495.0                              300.32
# 114780                     3169453.0                              362.55
# 114781                     3148484.0                              425.33
# 114782                     2876001.0                              267.98
#
#         stats.movement.timeBoostSpeed  stats.movement.timeSlowSpeed  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                              555.30                        650.93
# 4                              503.64                        791.24
# ...                               ...                           ...
# 114778                         785.33                        780.18
# 114779                         722.74                        926.25
# 114780                         885.47                        869.33
# 114781                         782.79                        900.10
# 114782                         720.80                       1112.30
#
#         stats.movement.timeGround  stats.movement.timeLowAir  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                          848.95                     484.98
# 4                          828.56                     491.61
# ...                           ...                        ...
# 114778                    1044.07                     786.99
# 114779                    1145.71                     665.92
# 114780                    1109.42                     866.58
# 114781                    1178.83                     794.42
# 114782                    1185.89                     783.85
#
#         stats.movement.timeHighAir  stats.movement.timePowerslide  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                            59.73                          26.50
# 4                            66.15                          14.97
# ...                            ...                            ...
# 114778                      123.52                          45.98
# 114779                      137.68                          37.89
# 114780                      141.34                          38.11
# 114781                      134.98                          46.76
# 114782                      131.35                          32.86
#
#         stats.movement.countPowerslide  stats.movement.avgPowerslideDuration  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                238.0                                  0.45
# 4                                118.0                                  0.52
# ...                                ...                                   ...
# 114778                           430.0                                  0.54
# 114779                           277.0                                  0.69
# 114780                           343.0                                  0.66
# 114781                           431.0                                  0.64
# 114782                           303.0                                  0.65
#
#         stats.movement.avgSpeedPercentage  stats.movement.percentSlowSpeed  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                               52.295654                        37.349822
# 4                               47.686957                        45.647354
# ...                                   ...                              ...
# 114778                          70.495652                        39.808488
# 114779                          66.330434                        47.365664
# 114780                          69.398550                        41.013903
# 114781                          69.391306                        42.472139
# 114782                          63.550724                        53.012460
#
#         stats.movement.percentBoostSpeed  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                              31.890524
# 4                              29.080756
# ...                                  ...
# 114778                         40.082287
# 114779                         37.159143
# 114780                         41.882811
# 114781                         37.292653
# 114782                         34.289255
#
#         stats.movement.percentSupersonicSpeed  stats.movement.percentGround  \
# 0                                         NaN                           NaN
# 1                                         NaN                           NaN
# 2                                         NaN                           NaN
# 3                                   10.759653                     48.740949
# 4                                    5.271888                     47.820808
# ...                                       ...                           ...
# 114778                              20.109225                     53.449258
# 114779                              15.475195                     58.571859
# 114780                              17.103289                     52.436878
# 114781                              20.235207                     55.947742
# 114782                              12.698286                     56.400649
#
#         stats.movement.percentLowAir  stats.movement.percentHighAir  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                          27.829345                       3.429702
# 4                          28.361062                       3.818127
# ...                              ...                            ...
# 114778                     40.156364                       6.394379
# 114779                     34.434626                       6.993513
# 114780                     40.852220                       6.710902
# 114781                     37.586672                       6.465583
# 114782                     37.257062                       6.342291
#
#         stats.positioning.avgDistanceToBall  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                   11074.0
# 4                                   11342.0
# ...                                     ...
# 114778                              14672.0
# 114779                              14358.0
# 114780                              16090.0
# 114781                              17287.0
# 114782                              16529.0
#
#         stats.positioning.avgDistanceToBallPossession  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                             10710.0
# 4                                             11209.0
# ...                                               ...
# 114778                                        13944.0
# 114779                                        13932.0
# 114780                                        14769.0
# 114781                                        17319.0
# 114782                                        16490.0
#
#         stats.positioning.avgDistanceToBallNoPossession  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                               11448.0
# 4                                               11555.0
# ...                                                 ...
# 114778                                          15049.0
# 114779                                          14763.0
# 114780                                          17546.0
# 114781                                          17290.0
# 114782                                          16474.0
#
#         stats.positioning.avgDistanceToMates  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                    13650.0
# 4                                    14180.0
# ...                                      ...
# 114778                               18351.0
# 114779                               18281.0
# 114780                               21603.0
# 114781                               21539.0
# 114782                               21340.0
#
#         stats.positioning.timeDefensiveThird  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                     650.96
# 4                                     690.61
# ...                                      ...
# 114778                                952.66
# 114779                                985.65
# 114780                                883.56
# 114781                               1036.73
# 114782                                929.54
#
#         stats.positioning.timeNeutralThird  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                   419.73
# 4                                   432.85
# ...                                    ...
# 114778                              604.26
# 114779                              613.56
# 114780                              707.21
# 114781                              697.44
# 114782                              737.40
#
#         stats.positioning.timeOffensiveThird  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                     322.99
# 4                                     262.83
# ...                                      ...
# 114778                                397.67
# 114779                                350.10
# 114780                                526.58
# 114781                                374.05
# 114782                                434.13
#
#         stats.positioning.timeDefensiveHalf  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                    876.96
# 4                                    912.70
# ...                                     ...
# 114778                              1278.62
# 114779                              1309.97
# 114780                              1225.43
# 114781                              1405.56
# 114782                              1294.45
#
#         stats.positioning.timeOffensiveHalf  stats.positioning.timeBehindBall  \
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                    516.42                            931.11
# 4                                    473.56                           1016.18
# ...                                     ...                               ...
# 114778                               675.97                           1407.75
# 114779                               639.34                           1477.06
# 114780                               891.93                           1448.80
# 114781                               702.67                           1637.66
# 114782                               806.63                           1512.77
#
#         stats.positioning.timeInfrontBall  stats.positioning.timeMostBack  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                  462.56                           377.8
# 4                                  370.13                           482.2
# ...                                   ...                             ...
# 114778                             546.85                           641.6
# 114779                             472.25                           704.7
# 114780                             668.55                           548.1
# 114781                             470.57                           860.3
# 114782                             588.32                           693.7
#
#         stats.positioning.timeMostForward  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                   499.5
# 4                                   429.9
# ...                                   ...
# 114778                              647.0
# 114779                              557.1
# 114780                              810.6
# 114781                              541.3
# 114782                              701.4
#
#         stats.positioning.goalsAgainstWhileLastDefender  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   3.0
# 4                                                   5.0
# ...                                                 ...
# 114778                                              3.0
# 114779                                              6.0
# 114780                                              0.0
# 114781                                              3.0
# 114782                                              7.0
#
#         stats.positioning.timeClosestToBall  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                     471.2
# 4                                     466.4
# ...                                     ...
# 114778                                619.2
# 114779                                594.4
# 114780                                743.6
# 114781                                636.7
# 114782                                671.7
#
#         stats.positioning.timeFarthestFromBall  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                        420.2
# 4                                        458.4
# ...                                        ...
# 114778                                   658.5
# 114779                                   667.2
# 114780                                   658.2
# 114781                                   771.8
# 114782                                   678.5
#
#         stats.positioning.percentDefensiveThird  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                     37.343181
# 4                                     39.814087
# ...                                         ...
# 114778                                48.849775
# 114779                                50.800555
# 114780                                41.480371
# 114781                                49.113336
# 114782                                43.902886
#
#         stats.positioning.percentOffensiveThird  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                     18.565859
# 4                                     15.193120
# ...                                         ...
# 114778                                20.288907
# 114779                                17.890228
# 114780                                25.092161
# 114781                                17.753795
# 114782                                20.824538
#
#         stats.positioning.percentNeutralThird  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                   24.090960
# 4                                   24.992793
# ...                                       ...
# 114778                              30.861314
# 114779                              31.309218
# 114780                              33.427473
# 114781                              33.132873
# 114782                              35.272576
#
#         stats.positioning.percentDefensiveHalf  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                    50.322415
# 4                                    52.634859
# ...                                        ...
# 114778                               65.581105
# 114779                               67.279504
# 114780                               57.673375
# 114781                               66.609378
# 114782                               61.253708
#
#         stats.positioning.percentOffensiveHalf  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                    29.677582
# 4                                    27.365140
# ...                                        ...
# 114778                               34.418896
# 114779                               32.720499
# 114780                               42.326628
# 114781                               33.390626
# 114782                               38.746291
#
#         stats.positioning.percentBehindBall  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                 53.436119
# 4                                 58.643027
# ...                                     ...
# 114778                            71.730683
# 114779                            75.816738
# 114780                            68.254115
# 114781                            77.625432
# 114782                            71.868180
#
#         stats.positioning.percentInfrontBall  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                  26.563880
# 4                                  21.356974
# ...                                      ...
# 114778                             28.269316
# 114779                             24.183262
# 114780                             31.745888
# 114781                             22.374571
# 114782                             28.131824
#
#         stats.positioning.percentMostBack  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                               22.671175
# 4                               28.940708
# ...                                   ...
# 114778                          33.903289
# 114779                          37.262074
# 114780                          26.900840
# 114781                          42.444606
# 114782                          33.982147
#
#         stats.positioning.percentMostForward  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                  29.968341
# 4                                  25.820933
# ...                                      ...
# 114778                             34.095660
# 114779                             29.337994
# 114780                             39.921532
# 114781                             26.502705
# 114782                             34.475283
#
#         stats.positioning.percentClosestToBall  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                    28.282206
# 4                                    27.982599
# ...                                        ...
# 114778                               32.535316
# 114779                               31.515554
# 114780                               36.603476
# 114781                               31.218314
# 114782                               33.026806
#
#         stats.positioning.percentFarthestFromBall  stats.demo.inflicted  \
# 0                                             NaN                   NaN
# 1                                             NaN                   NaN
# 2                                             NaN                   NaN
# 3                                       25.203142                   1.0
# 4                                       27.526223                   0.0
# ...                                           ...                   ...
# 114778                                  34.949747                   6.0
# 114779                                  35.091112                   4.0
# 114780                                  32.315387                   5.0
# 114781                                  38.042374                   9.0
# 114782                                  33.266817                   1.0
#
#         stats.demo.taken player.name player.accounts player.relevant  \
# 0                    NaN         NaN             NaN             NaN
# 1                    NaN         NaN             NaN             NaN
# 2                    NaN         NaN             NaN             NaN
# 3                    2.0         NaN             NaN             NaN
# 4                    5.0         NaN             NaN             NaN
# ...                  ...         ...             ...             ...
# 114778               8.0         NaN             NaN             NaN
# 114779              10.0         NaN             NaN             NaN
# 114780               4.0         NaN             NaN             NaN
# 114781               9.0         NaN             NaN             NaN
# 114782              11.0         NaN             NaN             NaN
#
#        player.team._id player.team.slug player.team.name player.team.region  \
# 0                  NaN              NaN              NaN                NaN
# 1                  NaN              NaN              NaN                NaN
# 2                  NaN              NaN              NaN                NaN
# 3                  NaN              NaN              NaN                NaN
# 4                  NaN              NaN              NaN                NaN
# ...                ...              ...              ...                ...
# 114778             NaN              NaN              NaN                NaN
# 114779             NaN              NaN              NaN                NaN
# 114780             NaN              NaN              NaN                NaN
# 114781             NaN              NaN              NaN                NaN
# 114782             NaN              NaN              NaN                NaN
#
#        player.team.image player.team.relevant player.coach player.substitute  \
# 0                    NaN                  NaN          NaN               NaN
# 1                    NaN                  NaN          NaN               NaN
# 2                    NaN                  NaN          NaN               NaN
# 3                    NaN                  NaN          NaN               NaN
# 4                    NaN                  NaN          NaN               NaN
# ...                  ...                  ...          ...               ...
# 114778               NaN                  NaN          NaN               NaN
# 114779               NaN                  NaN          NaN               NaN
# 114780               NaN                  NaN          NaN               NaN
# 114781               NaN                  NaN          NaN               NaN
# 114782               NaN                  NaN          NaN               NaN
#
#        tier       date
# 0         B 2018-07-07
# 1         B 2018-07-07
# 2         B 2018-07-07
# 3         S 2016-07-09
# 4         S 2016-07-09
# ...     ...        ...
# 114778    C 2022-12-07
# 114779    C 2022-12-07
# 114780    C 2022-12-07
# 114781    C 2022-12-07
# 114782    C 2022-12-07
#
# [114783 rows x 101 columns]

# %% [markdown]
# ## Playing around with some visualizations

# %% [markdown]
# First, we're going to want a convenient dataframe which holds all the player data——not separated into blue and orange team players. But we will want to know for each record, which team the player was on for that match, so we make sure to feature engineer a new column retaining that information.

# %%
player_df = pd.concat([blue_players, orange_players])
player_df = player_df.reset_index(drop=True)

# %%
# create our column of team colours. As we concatenated blue and orange, it's simlpy just
# blue for the first half of our records and orange for the second half
team_colour = np.repeat("Blue", len(blue_players))
team_colour = np.append(team_colour, np.repeat("Orange", len(blue_players)))

# %%
player_df['team_colour'] = team_colour
pd.options.display.max_columns = 10

# %%
player_df
# Out:
#         series_id                player._id    player.slug player.tag  \
# 0               0  5f3d8fdd95f40596eae23f4d   3f4d-caiotg1    CaioTG1
# 1               0  5f3d8fdd95f40596eae23f65   3f65-protomz    Protomz
# 2               0  5f99d0c8786e9eb85284db78   db78-noiisey    Noiisey
# 3               1  5f3d8fdd95f40596eae23d6e  3d6e-darkfire   DarkFire
# 4               1  5f3d8fdd95f40596eae23d72   3d72-torment    Torment
# ...           ...                       ...            ...        ...
# 229561      38259  5f3d8fdd95f40596eae23e01    3e01-torsos     Torsos
# 229562      38259  5f3d8fdd95f40596eae2412e    412e-amphis     Amphis
# 229563      38260  605108952629ffaa11f76dae       6dae-kv1        kv1
# 229564      38260  5f3d8fdd95f40596eae2433d       433d-sad        Sad
# 229565      38260  5f3d8fdd95f40596eae2433c    433c-nxghtt     nxghtt
#
#        player.country  ...  player.coach  player.substitute  tier       date  \
# 0                  br  ...           NaN                NaN     B 2018-07-07
# 1                  br  ...           NaN                NaN     B 2018-07-07
# 2                  br  ...           NaN                NaN     B 2018-07-07
# 3                  us  ...           NaN                NaN     S 2016-07-09
# 4                  us  ...           NaN                NaN     S 2016-07-09
# ...               ...  ...           ...                ...   ...        ...
# 229561             au  ...           NaN                NaN     C 2022-12-07
# 229562             au  ...           NaN                NaN     C 2022-12-07
# 229563             br  ...           NaN                NaN     C 2022-12-07
# 229564             br  ...           NaN                NaN     C 2022-12-07
# 229565             br  ...           NaN                NaN     C 2022-12-07
#
#         team_colour
# 0              Blue
# 1              Blue
# 2              Blue
# 3              Blue
# 4              Blue
# ...             ...
# 229561       Orange
# 229562       Orange
# 229563       Orange
# 229564       Orange
# 229565       Orange
#
# [229566 rows x 102 columns]

# %% [markdown]
# Let's begin by visualising demos inflicted in-game over time:

# %%
demos_over_time = sns.relplot(x="date", y="stats.demo.inflicted",
            kind="line", data=player_df, color='midnightblue',
            height=7.5, aspect=10/7.5)
# note this graph will take roughly 20-30 seconds to plot due to the size of the dataset——if we do not want confidence
# intervals we can set ci=None and it would be much faster

demos_over_time.ax.set_title("Average Demos over Time", fontsize=18)
demos_over_time.set_axis_labels("Date" , "Demos Inflicted Per Series", fontsize=15)

# %% [markdown]
# This is immediately pretty cool. We can see a clear increase in demos inflicted over time—and can make a reasonable assumption that this is the result of a shift towards more aggressive playstyles characterized by bumps, demos and boost steals. From the start of the RLCS to the current RLCS 2022-2023 season, we see an almost steady linear increase from an average of a single demo per player per series to about 4!

# %% [markdown]
# *Remark: Technically, not all series data in our dataset is directly from RLCS—there are collegiate matches, show matches, and others*

# %% [markdown]
# Next, let's split by tier and see if there are differences in number of demos inflicted between different skill levels of RLCS play.

# %%
player_df['tier'].unique() # 9 values
# Out:
# array(['B', 'S', 'C', 'A', 'Monthly', 'D', 'Weekly', 'Qualifier',
#        'Show Match'], dtype=object)

# %% [markdown]
# In order from more skilled to less experienced (+ some other categories at the end), we have:

# %%
tier_order = ['S', 'A', 'B', 'C', 'D', 'Monthly', 'Weekly', 'Show Match', 'Qualifier']
palette = sns.color_palette('flare', n_colors=9)

# %%
plt.subplots(1, figsize=(13, 9))
sns.violinplot(x="stats.demo.inflicted", y='tier', data=player_df,
               palette=palette, order=tier_order)
# Out:
# <AxesSubplot:xlabel='stats.demo.inflicted', ylabel='tier'>

# %% [markdown]
# There seem to be a few major outliers, which are making it difficult for us to compare. Let's check them out first, then graph again without them.

# %% [markdown]
# I could be looking too much into it, but aggressive playstyles by one team do tend to elicit increased aggressiveness by the opposing team as a countermeasure strategy (or if they're tilted and just on the hunt), leading to an abnormally high overall number of demos, and I would guess many of the outlier series displayed here played out that way.

# %%
player_df.groupby(["tier"])["stats.demo.inflicted"].max()
# Out:
# tier
# A             30.0
# B             49.0
# C             30.0
# D             13.0
# Monthly       24.0
# Qualifier     19.0
# S             30.0
# Show Match    23.0
# Weekly        15.0
# Name: stats.demo.inflicted, dtype: float64

# %% [markdown]
# Let's find which players and teams were involved in these outlier series, for fun. Maybe it'll yield cool insights too.

# %%
# convert above result into dictionary
max_demos_by_tier = player_df.groupby(["tier"])["stats.demo.inflicted"].max().to_dict()
idx = []

# iterate over keys and values, find indices of the players who achieved those max demos
for tier, num in max_demos_by_tier.items():
    index = player_df[(player_df['tier'] == tier) & (player_df['stats.demo.inflicted'] == num)].index
    idx.append(index)
    
idx = [y for x in idx for y in x] # flatten our list because there can be multiple players in a given tier
# with the same max demos

# locate those games
player_df.iloc[idx]
# Out:
#         series_id                player._id    player.slug player.tag  \
# 84384       28128  5f3d8fdd95f40596eae23d91  3d91-allushin   Allushin
# 108761      36253  5f3d8fdd95f40596eae240b2      40b2-comm       Comm
# 190097      25104  60c7085325eac8dd77d6d67e     d67e-woody      Woody
# 77120       25706  60241f4070e630f6d1013040    3040-bobsto     Bobsto
# 79130       26376  612a232287f814e9fb000213      0213-scar      scar.
# 118175       1130  5f3d8fdd95f40596eae2434b   434b-royales    Royales
# 193950      26389  5f3d8fdd95f40596eae2415a      415a-blau       Blau
# 195875      27030  60241f4070e630f6d1013040    3040-bobsto     Bobsto
# 187303      24173  60be08ea490bd8649dd30740      0740-tank       Tank
# 10635        3545  5f5ae820c6cbf591c568a3f7  a3f7-virtuoso   virtuoso
# 54860       18286  5f5ae9a5c6cbf591c568a8ec    a8ec-claven     Claven
# 171824      19013  5f3d8fdd95f40596eae24183   4183-zez0nix    Zez0nix
#
#        player.country  ...  player.team.relevant  player.coach  \
# 84384              ca  ...                   NaN           NaN
# 108761             us  ...                   NaN           NaN
# 190097             us  ...                   NaN           NaN
# 77120              us  ...                   NaN           NaN
# 79130              pt  ...                   NaN           NaN
# 118175             br  ...                   NaN           NaN
# 193950             pt  ...                   NaN           NaN
# 195875             us  ...                   NaN           NaN
# 187303             ph  ...                   NaN           NaN
# 10635              ie  ...                   NaN           NaN
# 54860              us  ...                   NaN           NaN
# 171824             sa  ...                   NaN           NaN
#
#         player.substitute        tier       date
# 84384                 NaN           A 2021-10-29
# 108761                NaN           A 2022-10-23
# 190097                NaN           B 2021-06-13
# 77120                 NaN           C 2021-08-14
# 79130                 NaN           D 2021-09-10
# 118175                NaN           D 2020-04-26
# 193950                NaN           D 2021-10-02
# 195875                NaN     Monthly 2021-09-18
# 187303                NaN   Qualifier 2021-06-13
# 10635                 NaN           S 2020-04-12
# 54860                 NaN  Show Match 2020-08-07
# 171824                NaN      Weekly 2020-09-25
#
# [12 rows x 101 columns]

# %% [markdown]
# Right away, if you're familiar with Rocket League professional players and the content creation scene, you'll recognize a few of these players like I did. Woody is a player famous for his merciless demo chasing—in fact, his YouTube channel description says "Rocket League Demolitions Expert | 120,000 Demos | 8,500 Exterminations".
#
# In addition, at the highest level of RLCS play, we have players like virtuoso and Comm, extremely well known for their well-perfected demo-heavy playstyles, diving in and out of the opponent's half landing opportunistic demos to clear out the defense without compromising their own positioning.

# %% [markdown]
# If we want to see which teams were involved, we can also do so by matching up the series_id to our main dataframe:

# %%
demo_idx = player_df.iloc[idx]["series_id"]
df.iloc[demo_idx]['matchup']
# Out:
# 28128               faze clan vs rbg esports
# 36253                nrg esports vs version1
# 25104          charlotte phoenix vs team exe
# 25706             fish tacos vs unreal units
# 26376    impulse gaming white vs we dem bots
# 1130                        free win vs pera
# 26389    impulse gaming black vs we dem bots
# 27030      integrity esports vs unreal units
# 24173                   equinox vs exodus hk
# 3545                       endpoint vs karen
# 18286                  cuties vs rbg esports
# 19013             5head vs momentum shifters
# Name: matchup, dtype: object

# %% [markdown]
# I won't lie, I don't recognize most of these teams. I know Allushin was a player for Faze, Comm for Version1, and virtuoso on Endpoint, but that's about it.

# %% [markdown]
# Anyway, back to our analysis. Let's remove some outliers and re-graph to see if we can find clear differences in average demos inflicted by tier. Looking at our earlier graph, a good cutoff seems to be somewhere like 18 demos, which removes 153 records.

# %%
plt.subplots(1, figsize=(13, 9))
sns.violinplot(x="stats.demo.inflicted", y='tier', data=player_df[player_df['stats.demo.inflicted'] < 18],
               palette=palette, order=tier_order)
# Out:
# <AxesSubplot:xlabel='stats.demo.inflicted', ylabel='tier'>

# %% [markdown]
# Okay, now there are visible differences. Amongst the numerical tiers S-A-B-C-D, we don't really see a difference, but in weekly and qualifier matches, the mean number of inflicted demos is significantly lower, and in show matches, it's significantly higher. I don't have a good explanation for this to be honest. I guess RLCS qualifier matches are more high-stakes and players thus tend to play more "clean"/conventional and risk-averse, whereas show matches have high viewership and players like to use these types of matches to practice riskier/newer playstyles.

# %% [markdown]
# For more confirmation of this trend, we have a table which displays the same information.

# %%
player_df.groupby(["tier"])["stats.demo.inflicted"].mean()
# Out:
# tier
# A             3.963016
# B             3.813511
# C             3.630605
# D             3.342105
# Monthly       3.896708
# Qualifier     2.670354
# S             3.569453
# Show Match    4.308057
# Weekly        3.041026
# Name: stats.demo.inflicted, dtype: float64

# %% [markdown]
# Let's see which individual players demo the most:

# %%
demo_players = player_df.groupby('player.tag')['stats.demo.inflicted'].mean().sort_values(ascending=False)[0:35]
demo_players = demo_players.reset_index()
demo_players[:10]
# I chose 35 because I wanted to include Comm, the current posterboy of successful demo-oriented playstyles at 
# the highest level of the RLCS.
# Out:
#         player.tag  stats.demo.inflicted
# 0            Woody             26.250000
# 1         paolotiu             14.000000
# 2          flikkas             14.000000
# 3            Kingy             13.000000
# 4  PerlikaPavel357             13.000000
# 5            Nacho             11.000000
# 6              Mad             11.000000
# 7           cambam             10.500000
# 8           Claven             10.373134
# 9         Kenshiro             10.333333

# %%
plt.subplots(1, figsize=(15, 6))
player_demos_graph = sns.barplot(x='player.tag', y='stats.demo.inflicted', data=demo_players,
                    palette=sns.color_palette("dark:red_r", n_colors=35), alpha=0.7)

plt.xticks(rotation=75);
player_demos_graph.set_title("Top 35 Players with the Greatest Average Number of Demos per Series", fontsize=18)
player_demos_graph.set_xlabel("Player IGN", fontsize=15) # IGN = in-game name
player_demos_graph.set_ylabel("Average Demos per Series", fontsize=15)
# Out:
# Text(0, 0.5, 'Average Demos per Series')

# %% [markdown]
# Quick remark: I would've also loved to investigate which teams demo the most, and whether a team's average number of demos correlates with their series winrate, but due to the design/setup of our data, this is very difficult to do because we only have demo data for individual players. We don't know what teams they belong on at the time of the matches, and teams constantly are being re-named, players are being traded, etc, so the numerous other variables are not constant by any means and we won't be able to get any clean insights in my opinion.

# %% [markdown]
# ### Shots taken vs. series outcome

# %% [markdown]
# Complicatedly, series outcome is stored in our main dataframe in a nested dictionary under the blue and orange columns—the winning team has a "winner: True" key-value pair while the losing team does not. We'll need to access it and pair it with our shots data to conduct our analysis. Since one team winning/or losing automatically implies the other losing/winning, we'll only need to look at one team's data, such as blue, and we'll impute the NaNs with Falses.

# %%
blue_wins = pd.json_normalize(df["blue"])['winner']
blue_wins = blue_wins.fillna(False)
blue_wins
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 38256     True
# 38257     True
# 38258     True
# 38259     True
# 38260     True
# Name: winner, Length: 38261, dtype: bool

# %% [markdown]
# Next, let's look at the ratio of blue team's shots to orange team's shots throughout the series. This gives us a good way to compare how many more/fewer shots a team took, versus their eventual series outcome.

# %%
shots_ratio = blue_players.groupby("series_id")["stats.core.shots"].sum() / orange_players.groupby("series_id")["stats.core.shots"].sum()
shots_ratio
# Out:
# series_id
# 0        1.518519
# 1        0.756757
# 2        0.633333
# 3        0.428571
# 4        1.375000
#            ...
# 38256    0.714286
# 38257    1.333333
# 38258    1.333333
# 38259    1.000000
# 38260    1.222222
# Name: stats.core.shots, Length: 38261, dtype: float64

# %% [markdown]
# Finally, we construct our simple bar graph:

# %%
plt.subplots(1, figsize=(10, 6))
shots = sns.barplot(x=blue_wins.map({True: 'Win', False: 'Loss'}), y=shots_ratio, 
                    palette=['deepskyblue', 'mediumvioletred'], alpha=0.7)

shots.set_title("Shot Ratio vs. Series Outcome", fontsize=18)
shots.set_xlabel("Series Outcome", fontsize=15)
shots.set_ylabel("Shot Ratio", fontsize=15)
# Out:
# Text(0, 0.5, 'Shot Ratio')

# %%
shots_ratio[blue_wins].mean(), shots_ratio[~blue_wins].mean()
# Out:
# (1.5364651922142467, 0.8620205116883434)

# %% [markdown]
# Perfect. This is pretty much as expected—if you're taking more shots on goal than your opponent, you're much more likely to win. In particular, when your team wins, you're on average taking 1.54 shots for every shot by the opposition, whereas on average you take only 0.862 shots for every shot when you lose.

# %% [markdown]
# ### Saves taken vs. series outcome

# %% [markdown]
# What about saves? Can they predict series outcome?

# %% [markdown]
# To be honest, no, I don't think so. If anything, more saves might predict a team's loss, because it means they are constantly on the backfoot and being pressured on defense. It implies a lack of ball possession and forced reactionary defense, to me at least. Good teams generally do not spend as much time on defense, at least on the goal line—they're challenging early, blocking threatening plays and shots before they even occur. But let's take a look at the data at least.

# %% [markdown]
# The procedure will be the same—we'll find the ratio of blue to orange team total saves and compare with the series outcome.

# %%
saves_ratio = blue_players.groupby("series_id")["stats.core.saves"].sum() / orange_players.groupby("series_id")["stats.core.saves"].sum()
saves_ratio = saves_ratio[saves_ratio != np.inf] # avoid division by zero, which in NumPy yields infinity!
saves_ratio
# Out:
# series_id
# 0        0.652174
# 1        0.733333
# 2        1.550000
# 3        1.700000
# 4        0.678571
#            ...
# 38256    1.500000
# 38257    0.761905
# 38258    0.885714
# 38259    1.100000
# 38260    0.888889
# Name: stats.core.saves, Length: 38259, dtype: float64

# %%
plt.subplots(1, figsize=(10, 6))
shots = sns.barplot(x=blue_wins.map({True: 'Win', False: 'Loss'}), y=saves_ratio, 
                    palette=['deepskyblue', 'mediumvioletred'], alpha=0.7)

shots.set_title("Saves Ratio vs. Series Outcome", fontsize=18)
shots.set_xlabel("Series Outcome", fontsize=15)
shots.set_ylabel("Saves Ratio", fontsize=15)
# Out:
# Text(0, 0.5, 'Saves Ratio')

# %%
saves_ratio[blue_wins].mean(), saves_ratio[~blue_wins].mean()
# Out:
# (0.9493189960477352, 1.191580511507665)

# %% [markdown]
# Indeed, this aligns with our hypothesis. Your team is in fact likely to have more saves if you lose the series. Now, this is of course not saying that if you make more saves, you are more likely to lose—it is not a causal relationship, but merely a correlational observation.

# %% [markdown]
# ### Next let's check out how shooting percentage (shot accuracy, essentially) correlates with series outcome.

# %%
shooting_pct = player_df.groupby(['series_id', 'team_colour'])['stats.core.shootingPercentage'].mean()
shooting_pct
# Out:
# series_id  team_colour
# 0          Blue           29.126984
#            Orange         25.637326
# 1          Blue           29.230769
#            Orange         43.589744
# 2          Blue           19.780220
#                             ...
# 38258      Orange         26.666667
# 38259      Blue           33.771930
#            Orange         25.952381
# 38260      Blue           35.454545
#            Orange         21.288515
# Name: stats.core.shootingPercentage, Length: 76522, dtype: float64

# %% [markdown]
# At this point we just need to massage our blue_wins array into something twice as long which is consistent with this series. In other words, we need to interweave NOT blue_wins in between to match this!

# %%
alt_wins = np.empty(2*len(blue_wins), dtype=blue_wins.dtype) # initialize empty array with correct size and dtype
# interweave blue wins and ~blue_wins (i.e. orange wins)
alt_wins[::2] = blue_wins
alt_wins[1::2] = ~blue_wins

alt_wins[0:15], len(alt_wins) # sanity check. indeed whenever blue wins, orange loses, and vice versa.
# Out:
# (array([ True, False, False,  True, False,  True, False,  True, False,
#          True,  True, False,  True, False, False]),
#  76522)

# %%
# once again, map the outcomes to more interpretable labels:
outcome = {True: 'Win', False: 'Loss'}

# %%
plt.subplots(1, figsize=(10, 6))
shot_accuracy = sns.barplot(x=[outcome[res] for res in alt_wins], y=shooting_pct,
                    palette=['deepskyblue', 'mediumvioletred'], alpha=0.7)

shot_accuracy.set_title("Shooting Percentage/Shot Accuracy vs. Series Outcome", fontsize=18)
shot_accuracy.set_xlabel("Series Outcome", fontsize=15)
shot_accuracy.set_ylabel("Shooting Percentage (%)", fontsize=15)
# Out:
# Text(0, 0.5, 'Shooting Percentage (%)')

# %%
shooting_pct[alt_wins].mean(), shooting_pct[~alt_wins].mean()
# Out:
# (31.18568103842318, 22.09610451908546)

# %% [markdown]
# (Note we didn't simply convert alt_wins to a pandas Series and then map to Win/Loss because it breaks the graph for some reason)

# %% [markdown]
# Indeed, shooting percentage appears to quite an important aspect of winning series. On average, players shoot more accurately by 9.09% when they win a series versus when they lose. Now, the complex dynamics of the game mean this isn't the full picture—sometimes you want to intentionally miss off the post to lure the defender out of the goal, or smash it off the corner as a pass to your teammate rather than directly shooting, but in general, in combination with our shots analysis, if you're taking more shots and putting more of them on net, you're likely to win more. Not too surprising but still interesting.

# %% [markdown]
# Next, let's see if shooting percentage has increased over time.

# %%
shooting_pct_over_time = sns.relplot(x="date", y="stats.core.shootingPercentage",
            kind="line", data=player_df, color='midnightblue',
            height=7.5, aspect=10/7.5)
# will take roughly 25 seconds
shooting_pct_over_time.ax.set_title("Average Shooting Percentage over Time (%)", fontsize=18)
shooting_pct_over_time.set_axis_labels("Date" , "Shooting Percentage (%)", fontsize=15)

# %% [markdown]
# Nope. This is...somewhat interesting. I figured as players got better, they would put more shots on net, but as previously mentioned, winning games isn't purely about taking a shot at the goal at every opportunity. Also, that spike near the end of 2019 is intriguing.

# %% [markdown]
# Also, an interesting note is that in some games, players actually have a higher than 100% shooting percentage; in other words, fewer shots than goals! I assume this is due to things like the opponent own-goaling (in Rocket League, when someone scores an own goal, it is attributed to the player on the opposition team who last made contact with the ball).

# %%
rating_over_time = sns.relplot(x="date", y="advanced.rating",
            kind="line", data=player_df, color='midnightblue',
            height=7.5, aspect=10/7.5)
# will take roughly 30 seconds
shooting_pct_over_time.ax.set_title("Average Player Rating over Time", fontsize=18)
shooting_pct_over_time.set_axis_labels("Date" , "Average Player Rating", fontsize=15)

# %% [markdown]
# Interesting that shooting percentage and rating seem to correlate so strongly with each other, despite the fact that player rating is likely an advanced composite combining many different statistics. Also, to my knowledge, Octane ratings tend to be around 0.5-1.5, so the outliers here are extremely unusual, especially with that period near the end of 2019 appearing in our graph again. Let's investigate those series.

# %% [markdown]
# ### Investigating outliers

# %% [markdown]
# Let's peer into the series in which players had a rating of more than 4.

# %%
rating_outliers = player_df[(player_df['advanced.rating'] > 4)]
rating_outliers
# Out:
#         series_id                player._id       player.slug   player.tag  \
# 1684          561  5f3d8fdd95f40596eae23eb6  3eb6-firstkiller  Firstkiller
# 1792          597  5f5ac3c9cf2177bd68e21d89    1d89-majicbear    majicbear
# 2147          715  5f3d8fdd95f40596eae23eb6  3eb6-firstkiller  Firstkiller
# 2422          807  5f3d8fdd95f40596eae23dad   3dad-fairy-peak  Fairy Peak!
# 2545          848  5f3d8fdd95f40596eae23f95      3f95-okhalid      oKhaliD
# ...           ...                       ...               ...          ...
# 192514      25910  5f3d8fdd95f40596eae2444d         444d-oski         Oski
# 222243      35820  63242914da9d7ca1c7bb3e76     3e76-azapatos     aZapatos
# 228666      37961  5f3d8fdd95f40596eae23eba      3eba-ayyjayy      AYYJAYY
# 228965      38060  5f3d8fdd95f40596eae24233       4233-lorely       Lorely
# 228985      38067  63393ebac437fde7e02dcc92        cc92-shadi        shadi
#
#        player.country  ...  player.coach  player.substitute  tier       date  \
# 1684               us  ...           NaN                NaN     B 2020-05-28
# 1792               us  ...           NaN                NaN     B 2020-05-27
# 2147               us  ...           NaN                NaN     B 2020-05-29
# 2422               fr  ...           NaN                NaN     B 2020-06-03
# 2545               sa  ...           NaN                NaN     B 2020-06-05
# ...               ...  ...           ...                ...   ...        ...
# 192514             pl  ...           NaN                NaN     B 2021-08-05
# 222243             mx  ...           NaN                NaN     B 2022-09-10
# 228666             us  ...           NaN                NaN     B 2022-11-15
# 228965             tr  ...           NaN                NaN     B 2022-11-17
# 228985             sa  ...           NaN                NaN     B 2022-11-17
#
#         team_colour
# 1684           Blue
# 1792           Blue
# 2147           Blue
# 2422           Blue
# 2545           Blue
# ...             ...
# 192514       Orange
# 222243       Orange
# 228666       Orange
# 228965       Orange
# 228985       Orange
#
# [163 rows x 102 columns]

# %% [markdown]
# Next we look at what the matchups were.

# %%
rating_outlier_matches = df.iloc[rating_outliers['series_id']]
rating_outlier_matches['matchup'].value_counts()
# Out:
# apparentlyjack vs luiisp        3
# jbot vs majicbear               3
# rogue vs spacestation gaming    2
# tbd vs tbd                      2
# eekso vs fairy peak             2
#                                ..
# death lfy vs exotiik            1
# chronic vs lionblaze            1
# dead monster vs oscillon        1
# noly vs scrub killa             1
# shadi vs toxiic                 1
# Name: matchup, Length: 146, dtype: int64

# %%
rating_outlier_matches['event_name'].value_counts()
# Out:
# The Salt Mine 2 North America                        41
# The Salt Mine 2 Europe                               40
# The Salt Mine 1 North America                        13
# The Salt Mine 1 Europe                               12
# Just Win                                             10
# Feer's Fall 5K                                        6
# Fusion North America 1v1                              5
# NGL Rocketeers Championship                           4
# Fusion Europe 1v1                                     3
# The Salt Mine 1 Finals                                3
# DreamHack Beyond Boost Cup Europe 2021 1v1            3
# The Gold Mine Europe                                  3
# Battle of the Bulls                                   2
# ProDrops AMENA 1v1 Invitational                       2
# The Gold Mine North America                           2
# Turf Wars                                             2
# DreamHack Beyond Boost Cup North America 2021 1v1     2
# Salt Mine Underground 1                               2
# Salt Mine Underground 4                               2
# Salt Mine Underground 5                               2
# Salt Mine Underground 2                               1
# Salt Mine Underground 7                               1
# Friday Night Duels                                    1
# Intel World Open Asia Maritime & Oceania New Z...     1
# Name: event_name, dtype: Int64

# %% [markdown]
# Upon seeing this, I had an ohhhhh moment. Of course! There apparently are 1v1 tournaments in the data——Salt Mine, Just Win, Feer's Fall 5K, the 1v1 matches in the Fusion tournament, Gold Mine, ProDrops, etc. 1v1 Rocket League games tend to be extremely high-scoring, and individual players can rack up tons of goals and saves per game, often with a score of more than 1000. No wonder there are so many games with high octane ratings.

# %% [markdown]
# From this point on it's really up to us whether we want to keep 1v1 stats as part of our data or separate it out/ignore it. Personally, I think the more gameplay data the better——we'll just have to keep in mind what variables may have outliers that arise from the 1v1 data and deal with them on a case-by-case basis. For example, player score, goals, saves, rating, and goal participation would be drastically different, and even factors like average distance to the ball would be different because there you're the only attacker (and defender) on your "team".

# %% [markdown]
# ### Continuing our exploration—boost stolen:

# %%
plt.subplots(1, figsize=(12,8))
boost_stolen = sns.histplot(data=player_df, x='stats.boost.amountStolen',
             stat='proportion', bins=250, kde=True, color='firebrick')

boost_stolen.set_title("Distribution of Average Boost Stolen Per Player Per Series", fontsize=18)
boost_stolen.set_xlabel("Average Boost Stolen", fontsize=15) # IGN = in-game name
boost_stolen.set_ylabel("Frequency", fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Okay, this isn't that insightful. The amount of boost stolen correlates with other variables/playstyles:

# %%
plt.subplots(1, figsize=(12,8))
sns.scatterplot(data = player_df, x="stats.boost.amountStolen",
                                       y='stats.core.shots')
# Out:
# <AxesSubplot:xlabel='stats.boost.amountStolen', ylabel='stats.core.shots'>

# %% [markdown]
# Both shots and goals vaguely, weakly correlate like so. If you're stealing boost, you're on the opponent's half, so it's likely that your team is attacking offensively and opportunities are being created.

# %%
plt.subplots(1, figsize=(12,8))
boost_stolen_scatter = sns.scatterplot(data = player_df, x="stats.boost.amountStolen",
                                       y='stats.boost.avgAmount')

# %% [markdown]
# Unsurprisingly, variables such as average boost amount, boost used per minute (bpm), and boost collected per minute (bcpm) are highly correlated. So, players who are stealing more boost typically have more in the tank on average, at any given moment.

# %% [markdown]
# ### Some final variables to look at:

# %% [markdown]
# #### Boost amount

# %%
plt.subplots(1, figsize=(12,8))
sns.histplot(data=player_df, x='stats.boost.avgAmount',
             stat='proportion', bins=250, kde=True, color='firebrick')
# Out:
# <AxesSubplot:xlabel='stats.boost.avgAmount', ylabel='Proportion'>

# %% [markdown]
# This is extremely perplexing to me—not necessarily the multimodal nature of the distribution, but the fact that boost averages regularly exceed 100. I'm not sure I understand this variable enough to use it in any capacity, because given how boost works in-game, I assumed average boost amount must range strictly from 0 to 100 inclusive. For completeness, though, we can just treat it as a dimensionless value. In comparison, it must still make some logical sense. Here's the top 30 players with the greatest average boost amount in a single series (not the average of all the games they've ever played):

# %%
player_df.sort_values(by=['stats.boost.avgAmount'], ascending=False)[:30]['player.tag']
# Out:
# 115597       kuxir97
# 814         Paschy90
# 177787       ReaLize
# 105115          Tahz
# 115598    Markydooda
# 536            Rizzo
# 177786       Akira90
# 98104         Jordan
# 191862       Rizex45
# 223530           ajg
# 66926           ThO.
# 199061    Wee_Casper
# 9569          Flakes
# 98842         JWeyts
# 69530          Lexim
# 115596     M1k3Rules
# 30165          Shock
# 227137           pzy
# 104238       CaioTG1
# 556            Sikii
# 57864      Roll Dizz
# 141707         Speed
# 205787        saizen
# 93398         Tenhow
# 101075    bananahead
# 6897             Kia
# 111878          Andy
# 191304          Andy
# 105092       CHEESE.
# 112335          alty
# Name: player.tag, dtype: object

# %% [markdown]
# You could call it cherry-picking, or specifically looking for standout performances in the boost management department. But either way, this list displays a number of prominent professional players—in fact, I recognize nearly all of them. From European legends like kuxir97, Paschy90, M1k3Rules, and Markydooda to Japanese player ReaLize, to former G2 player Rizzo, Dutch 1v1 expert Flakes, Brazilian CaioTG1 ("The Great One"), Australian pro bananahead...the list goes on.

# %%
plt.subplots(1, figsize=(12,8))
sns.histplot(data=player_df, x='stats.movement.avgSpeed',
             stat='proportion', bins=250, kde=True, color='firebrick')
# Out:
# <AxesSubplot:xlabel='stats.movement.avgSpeed', ylabel='Proportion'>

# %% [markdown]
# Once again, there's a highly multimodal distribution, but this time we know we don't need to worry about the units. Speed and distance in Rocket League are measured in something called "Unreal Units" (this comes from Unreal Engine 4, which powers the game), which has an estimated conversion to real-life meters and whatnot, but that's clearly not important.

# %%
fastest_players = player_df.groupby('player.tag')['stats.movement.avgSpeed'].mean().sort_values(ascending=False).reset_index()
fastest_players
# Out:
#           player.tag  stats.movement.avgSpeed
# 0              Bency             11394.000000
# 1             Reeyko             10851.500000
# 2               jzm.             10559.666667
# 3              LUCID             10492.000000
# 4              esper             10452.000000
# ...              ...                      ...
# 5220            yoyo                      NaN
# 5221  yumi cheeseman                      NaN
# 5222      yung clipz                      NaN
# 5223        zOctanEz                      NaN
# 5224            zsoo                      NaN
#
# [5225 rows x 2 columns]

# %% [markdown]
# Okay, so I don't recognize these players. Let's use our knowledge of the scene and try locating some players who are famous for their speed.
#
# As of December 2022, the Saudi Arabian Team Falcons consisting of Ahmad, Okhalid, and Trk511 are a force to be reckoned with, dominating the region with violent mechanical ability and precision. Ahmad is commonly considered one of the fastest players ever on the pitch—if you watch his gameplay, he always seems to be supersonic, zooming around the pitch. But Saudi Arabia is full of mechanical wonder kids—what about up and coming players new to / not yet in RLCS? What about the top 16 teams in the new RLCS 2022-2023 season and others?

# %%
possibly_fast = ['Ahmad', 'oKhaliD', 'trk511', 'Nwpo',  'Kiileerrz.', 'Rw9.', 'Nadr',
                'itachi', 'vatira.', 'ExoTiiK', 'Archie', 'Joreuz', 'oaly.', 'ApparentlyJack',
                'Chronic', 'noly', 'Sad', 'nxghtt', 'kv1', 'Torment', 'Comm', 'BeastMode',
                'AcroniK.', 'Atow.', 'Oski', 'Firstkiller', 'Sypical', 'mist', 'Joyo', 'rise.',
                 'AztraL', 'JKnaps', 'Chicago', 'Atomic', 'Amphis', 'Torsos', 'Fever', 'Arsenal',
                 'Daniel', 'Lj', 'Aztromick', 'Lostt.', 'Bemmz', 'Kash', 'Relatingwave', 'eekso',
                 'Scrub', 'Superlachie', 'bananahead', 'virtuoso', 'ReaLize', 'Kamii', 'GarrettG',
                 'jstn.', 'Squishy', 'M0nkey M00n', 'Extra', 'Seikoo', 'Fairy Peak!', 'Kaydop',
                 'Scrub Killa', 'Alpha54', 'Turbopolsa', 'CaioTG1', 'caard', 'yanxnz', 'AYYJAYY',
                 'retals', 'majicbear']

# %% [markdown]
# Here, we've gathered 69 famous and well-performing recent players. Recall that our full dataset has 5225 unique players.

# %%
fastest_players[fastest_players['player.tag'].isin(possibly_fast)]
# Out:
#       player.tag  stats.movement.avgSpeed
# 257       Atomic              7240.250951
# 268       Seikoo              7195.915254
# 269      vatira.              7194.037975
# 276         Nwpo              7169.625000
# 300    Aztromick              7063.831050
# ...          ...                      ...
# 1202      Lostt.              6158.862069
# 1258  Kiileerrz.              6130.088235
# 1526     Chronic              5978.275000
# 1530     ExoTiiK              5976.382199
# 1623         Sad              5928.398524
#
# [69 rows x 2 columns]

# %%
print(f'These players are on average in the top {round(sum(fastest_players[fastest_players["player.tag"].isin(possibly_fast)].index) / 69 / 5225 * 100, 2)}%.')
# Out:
# These players are on average in the top 12.47%.

# %%
# Top 10 fastest players among our chosen list.
fastest_players[fastest_players['player.tag'].isin(possibly_fast)][:10]
# Out:
#     player.tag  stats.movement.avgSpeed
# 257     Atomic              7240.250951
# 268     Seikoo              7195.915254
# 269    vatira.              7194.037975
# 276       Nwpo              7169.625000
# 300  Aztromick              7063.831050
# 301     AztraL              7063.480392
# 315       mist              7008.634686
# 325     retals              6988.832143
# 348    Chicago              6916.404389
# 365      Extra              6887.511278

# %% [markdown]
# Not too surprised. Players like Seikoo, Vatira, and AztraL are speed demons and seem to be everywhere at once, shutting down the opponent's offense, applying counterpressure and cleanly beating players to the ball. Note that two out of three players on G2 and BDS are in this top 10. Also note that Nwpo has no RLCS experience—he is too young still, so all of his gameplay in our dataset is of 1v1 matches. I wouldn't be at all surprised if he keeps up this performance when he does enter RLCS, though.

# %%
plt.subplots(1, figsize=(12,8))
powerslide = sns.histplot(data=player_df, x='stats.movement.countPowerslide',
             stat='proportion', bins=250, kde=True, hue='tier', color='firebrick')

powerslide.set_title("Distribution of Average Powerslide Count Per Series By Tier", fontsize=18)
powerslide.set_xlabel("Average Powerslide Count", fontsize=15) # IGN = in-game name
powerslide.set_ylabel("Frequency", fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
player_df.groupby('tier')['stats.movement.countPowerslide'].mean().sort_values(ascending=False)
# Out:
# tier
# S             336.077170
# Show Match    327.227488
# A             309.882128
# B             296.759951
# Monthly       292.655556
# C             291.534572
# Weekly        262.825641
# D             245.508772
# Qualifier     216.350295
# Name: stats.movement.countPowerslide, dtype: float64

# %% [markdown]
# *This* is actually quite interesting. It seems there is a very clear positive correlation between tier and powerslide count——higher-rated, more skilled players consistently powerslide more in their games.

# %% [markdown]
# ### TO-DO left: (histogram, check over time, split by tier, split by country, etc.)
#
# #### (wait actually go back and split everything by country just for fun!!!
#
# Finish powerslide count (stats.movement.countPowerslide)
# -Percentage time on the ground/low air/high air (stats.movement.percentGround) (pie chart? side-by-side bar charts? stacked bar?)
#
# -Average distance to ball (stats.positioning.avgDistanceToBall)
# -Percentage of time in defensive/neutral/offensive third, defensive/offensive half (stats.positioning.percentOffensiveThird / stats.positioning.percentNeutralThird) (pie chart? side-by-side bar charts? stacked bar?)
# -Time behind/in front of the ball (stats.positioning.percentBehindBall / stats.positioning.percentInfrontBall) (pie chart? side-by-side bar charts? stacked bar?) (hmm is this 100% pie chart tho? does it actually add to 100? honestly, check for all of them just in case)
# -Number of goals against while last defender (stats.positioning.goalsAgainstWhileLastDefender) (definitely cool, see if you can see 1s players in the low numbers. or great goalline defenders)
#
# **aim for some variety, try new sns functions like joint, pair, reg/lm w/ regression lines and annotate R^2 values, maybe add shaded sections like in Pic 16 HW, etc.**
